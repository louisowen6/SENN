# %% [markdown]
# # Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from dtaidistance import dtw,clustering

# %% [markdown]
# # Import Data

# %%
df_yfinance_full_AAPL = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_AAPL.csv')
df_yfinance_full_AAPL.index=pd.to_datetime(df_yfinance_full_AAPL['Date'].reset_index(drop=True)+' '+df_yfinance_full_AAPL['time'].reset_index(drop=True))
df_yfinance_full_AAPL=df_yfinance_full_AAPL.drop(['Date','time'],1)


df_yfinance_full_AXP = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_AXP.csv')
df_yfinance_full_AXP.index=pd.to_datetime(df_yfinance_full_AXP['Date'].reset_index(drop=True)+' '+df_yfinance_full_AXP['time'].reset_index(drop=True))
df_yfinance_full_AXP=df_yfinance_full_AXP.drop(['Date','time'],1)


df_yfinance_full_BA = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_BA.csv')
df_yfinance_full_BA.index=pd.to_datetime(df_yfinance_full_BA['Date'].reset_index(drop=True)+' '+df_yfinance_full_BA['time'].reset_index(drop=True))
df_yfinance_full_BA=df_yfinance_full_BA.drop(['Date','time'],1)

 
df_yfinance_full_CAT = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_CAT.csv')
df_yfinance_full_CAT.index=pd.to_datetime(df_yfinance_full_CAT['Date'].reset_index(drop=True)+' '+df_yfinance_full_CAT['time'].reset_index(drop=True))
df_yfinance_full_CAT=df_yfinance_full_CAT.drop(['Date','time'],1)


df_yfinance_full_CSCO = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_CSCO.csv')
df_yfinance_full_CSCO.index=pd.to_datetime(df_yfinance_full_CSCO['Date'].reset_index(drop=True)+' '+df_yfinance_full_CSCO['time'].reset_index(drop=True))
df_yfinance_full_CSCO=df_yfinance_full_CSCO.drop(['Date','time'],1)

 
df_yfinance_full_CVX = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_CVX.csv')
df_yfinance_full_CVX.index=pd.to_datetime(df_yfinance_full_CVX['Date'].reset_index(drop=True)+' '+df_yfinance_full_CVX['time'].reset_index(drop=True))
df_yfinance_full_CVX=df_yfinance_full_CVX.drop(['Date','time'],1)

 
df_yfinance_full_DIS = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_DIS.csv')
df_yfinance_full_DIS.index=pd.to_datetime(df_yfinance_full_DIS['Date'].reset_index(drop=True)+' '+df_yfinance_full_DIS['time'].reset_index(drop=True))
df_yfinance_full_DIS=df_yfinance_full_DIS.drop(['Date','time'],1)


df_yfinance_full_DOW = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_DOW.csv')
df_yfinance_full_DOW.index=pd.to_datetime(df_yfinance_full_DOW['Date'].reset_index(drop=True)+' '+df_yfinance_full_DOW['time'].reset_index(drop=True))
df_yfinance_full_DOW=df_yfinance_full_DOW.drop(['Date','time'],1)

 
df_yfinance_full_GS = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_GS.csv')
df_yfinance_full_GS.index=pd.to_datetime(df_yfinance_full_GS['Date'].reset_index(drop=True)+' '+df_yfinance_full_GS['time'].reset_index(drop=True))
df_yfinance_full_GS=df_yfinance_full_GS.drop(['Date','time'],1)

  
df_yfinance_full_HD = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_HD.csv')
df_yfinance_full_HD.index=pd.to_datetime(df_yfinance_full_HD['Date'].reset_index(drop=True)+' '+df_yfinance_full_HD['time'].reset_index(drop=True))
df_yfinance_full_HD=df_yfinance_full_HD.drop(['Date','time'],1)

  
df_yfinance_full_IBM = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_IBM.csv')
df_yfinance_full_IBM.index=pd.to_datetime(df_yfinance_full_IBM['Date'].reset_index(drop=True)+' '+df_yfinance_full_IBM['time'].reset_index(drop=True))
df_yfinance_full_IBM=df_yfinance_full_IBM.drop(['Date','time'],1)

 
df_yfinance_full_INTC = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_INTC.csv')
df_yfinance_full_INTC.index=pd.to_datetime(df_yfinance_full_INTC['Date'].reset_index(drop=True)+' '+df_yfinance_full_INTC['time'].reset_index(drop=True))
df_yfinance_full_INTC=df_yfinance_full_INTC.drop(['Date','time'],1)

 
df_yfinance_full_JNJ = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_JNJ.csv')
df_yfinance_full_JNJ.index=pd.to_datetime(df_yfinance_full_JNJ['Date'].reset_index(drop=True)+' '+df_yfinance_full_JNJ['time'].reset_index(drop=True))
df_yfinance_full_JNJ=df_yfinance_full_JNJ.drop(['Date','time'],1)

 
df_yfinance_full_JPM = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_JPM.csv')
df_yfinance_full_JPM.index=pd.to_datetime(df_yfinance_full_JPM['Date'].reset_index(drop=True)+' '+df_yfinance_full_JPM['time'].reset_index(drop=True))
df_yfinance_full_JPM=df_yfinance_full_JPM.drop(['Date','time'],1)

 
df_yfinance_full_KO = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_KO.csv')
df_yfinance_full_KO.index=pd.to_datetime(df_yfinance_full_KO['Date'].reset_index(drop=True)+' '+df_yfinance_full_KO['time'].reset_index(drop=True))
df_yfinance_full_KO=df_yfinance_full_KO.drop(['Date','time'],1)


df_yfinance_full_MCD = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_MCD.csv')
df_yfinance_full_MCD.index=pd.to_datetime(df_yfinance_full_MCD['Date'].reset_index(drop=True)+' '+df_yfinance_full_MCD['time'].reset_index(drop=True))
df_yfinance_full_MCD=df_yfinance_full_MCD.drop(['Date','time'],1)


df_yfinance_full_MMM = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_MMM.csv')
df_yfinance_full_MMM.index=pd.to_datetime(df_yfinance_full_MMM['Date'].reset_index(drop=True)+' '+df_yfinance_full_MMM['time'].reset_index(drop=True))
df_yfinance_full_MMM=df_yfinance_full_MMM.drop(['Date','time'],1)


df_yfinance_full_MRK = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_MRK.csv')
df_yfinance_full_MRK.index=pd.to_datetime(df_yfinance_full_MRK['Date'].reset_index(drop=True)+' '+df_yfinance_full_MRK['time'].reset_index(drop=True))
df_yfinance_full_MRK=df_yfinance_full_MRK.drop(['Date','time'],1)


df_yfinance_full_MSFT = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_MSFT.csv')
df_yfinance_full_MSFT.index=pd.to_datetime(df_yfinance_full_MSFT['Date'].reset_index(drop=True)+' '+df_yfinance_full_MSFT['time'].reset_index(drop=True))
df_yfinance_full_MSFT=df_yfinance_full_MSFT.drop(['Date','time'],1)


df_yfinance_full_NKE = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_NKE.csv')
df_yfinance_full_NKE.index=pd.to_datetime(df_yfinance_full_NKE['Date'].reset_index(drop=True)+' '+df_yfinance_full_NKE['time'].reset_index(drop=True))
df_yfinance_full_NKE=df_yfinance_full_NKE.drop(['Date','time'],1)

 
df_yfinance_full_PFE = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_PFE.csv')
df_yfinance_full_PFE.index=pd.to_datetime(df_yfinance_full_PFE['Date'].reset_index(drop=True)+' '+df_yfinance_full_PFE['time'].reset_index(drop=True))
df_yfinance_full_PFE=df_yfinance_full_PFE.drop(['Date','time'],1)


df_yfinance_full_PG = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_PG.csv')
df_yfinance_full_PG.index=pd.to_datetime(df_yfinance_full_PG['Date'].reset_index(drop=True)+' '+df_yfinance_full_PG['time'].reset_index(drop=True))
df_yfinance_full_PG=df_yfinance_full_PG.drop(['Date','time'],1)

 
df_yfinance_full_TRV = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_TRV.csv')
df_yfinance_full_TRV.index=pd.to_datetime(df_yfinance_full_TRV['Date'].reset_index(drop=True)+' '+df_yfinance_full_TRV['time'].reset_index(drop=True))
df_yfinance_full_TRV=df_yfinance_full_TRV.drop(['Date','time'],1)

  
df_yfinance_full_UNH = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_UNH.csv')
df_yfinance_full_UNH.index=pd.to_datetime(df_yfinance_full_UNH['Date'].reset_index(drop=True)+' '+df_yfinance_full_UNH['time'].reset_index(drop=True))
df_yfinance_full_UNH=df_yfinance_full_UNH.drop(['Date','time'],1)

 
df_yfinance_full_UTX = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_UTX.csv')
df_yfinance_full_UTX.index=pd.to_datetime(df_yfinance_full_UTX['Date'].reset_index(drop=True)+' '+df_yfinance_full_UTX['time'].reset_index(drop=True))
df_yfinance_full_UTX=df_yfinance_full_UTX.drop(['Date','time'],1)

  
df_yfinance_full_V = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_V.csv')
df_yfinance_full_V.index=pd.to_datetime(df_yfinance_full_V['Date'].reset_index(drop=True)+' '+df_yfinance_full_V['time'].reset_index(drop=True))
df_yfinance_full_V=df_yfinance_full_V.drop(['Date','time'],1)


df_yfinance_full_VZ = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_VZ.csv')
df_yfinance_full_VZ.index=pd.to_datetime(df_yfinance_full_VZ['Date'].reset_index(drop=True)+' '+df_yfinance_full_VZ['time'].reset_index(drop=True))
df_yfinance_full_VZ=df_yfinance_full_VZ.drop(['Date','time'],1)


df_yfinance_full_WBA = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_WBA.csv')
df_yfinance_full_WBA.index=pd.to_datetime(df_yfinance_full_WBA['Date'].reset_index(drop=True)+' '+df_yfinance_full_WBA['time'].reset_index(drop=True))
df_yfinance_full_WBA=df_yfinance_full_WBA.drop(['Date','time'],1)

 
df_yfinance_full_WMT = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_WMT.csv')
df_yfinance_full_WMT.index=pd.to_datetime(df_yfinance_full_WMT['Date'].reset_index(drop=True)+' '+df_yfinance_full_WMT['time'].reset_index(drop=True))
df_yfinance_full_WMT=df_yfinance_full_WMT.drop(['Date','time'],1)


df_yfinance_full_XOM = pd.read_csv('C:/Users/Louis Owen/Desktop/ICoDSA 2020/SENN/Dataset/df_yfinance_full_XOM.csv')
df_yfinance_full_XOM.index=pd.to_datetime(df_yfinance_full_XOM['Date'].reset_index(drop=True)+' '+df_yfinance_full_XOM['time'].reset_index(drop=True))
df_yfinance_full_XOM=df_yfinance_full_XOM.drop(['Date','time'],1)

# %% [markdown]
# # Segmentation

# %%
data=[
      np.array(df_yfinance_AAPL['Open'].tolist(),dtype=np.double),
      np.array(df_yfinance_AXP['Open'].tolist()),
      np.array(df_yfinance_BA['Open'].tolist()),
      np.array(df_yfinance_full_CAT['Open'].tolist()),
      np.array(df_yfinance_full_CSCO['Open'].tolist()),
      np.array(df_yfinance_full_CVX['Open'].tolist()),
      np.array(df_yfinance_full_DIS['Open'].tolist()),
      np.array(df_yfinance_full_DOW['Open'].tolist()),
      np.array(df_yfinance_full_GS['Open'].tolist()),
      np.array(df_yfinance_full_HD['Open'].tolist()),
      np.array(df_yfinance_full_IBM['Open'].tolist()),
      np.array(df_yfinance_full_INTC['Open'].tolist()),
      np.array(df_yfinance_full_JNJ['Open'].tolist()),
      np.array(df_yfinance_full_JPM['Open'].tolist()),
      np.array(df_yfinance_full_KO['Open'].tolist()),
      np.array(df_yfinance_full_MCD['Open'].tolist()),
      np.array(df_yfinance_full_MMM['Open'].tolist()),
      np.array(df_yfinance_full_MRK['Open'].tolist()),
      np.array(df_yfinance_full_MSFT['Open'].tolist()),
      np.array(df_yfinance_full_NKE['Open'].tolist()),
      np.array(df_yfinance_full_PFE['Open'].tolist()),
      np.array(df_yfinance_full_PG['Open'].tolist()),
      np.array(df_yfinance_full_TRV['Open'].tolist()),
      np.array(df_yfinance_full_UNH['Open'].tolist()),
      np.array(df_yfinance_full_UTX['Open'].tolist()),
      np.array(df_yfinance_full_V['Open'].tolist()),
      np.array(df_yfinance_full_VZ['Open'].tolist()),
      np.array(df_yfinance_full_WBA['Open'].tolist()),
      np.array(df_yfinance_full_WMT['Open'].tolist()),
      np.array(df_yfinance_full_XOM['Open'].tolist())]

# %%
# model_0 = clustering.Hierarchical(dtw.distance_matrix_fast, {})
# model = clustering.HierarchicalTree(model_0)
model = clustering.LinkageTree(dtw.distance_matrix_fast, {}) #Complete linkage with DTW as distance matrix
cluster_idx = model.fit(data)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 20))
show_ts_label = lambda idx: "ts-" + str(idx)
model.plot(axes=ax, show_ts_label=show_ts_label,
           show_tr_label=True, ts_label_margin=-10,
           ts_left_margin=10, ts_sample_length=1)
# Out:
# (None, array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f29f5590080>,
# ...
#        dtype=object))

# %% [markdown]
# Threshold dipilih di 661.18
#
# Segmen A: ts-0 (AAPL)
#
# Segmen B:  ts-16 (MMM)
#
# Segmen C: ts-25 (V)
#
# Segmen D: ts-23 (UNH)
#
# Segmen E: ts-2 (BA)
#
# Segmen F:  ts-20 (PFE)
#
# Segmen G:  ts-8 (GS), ts-9 (HD), ts-15 (MCD)
#
# Segmen H:  ts-17 (MRK), ts-19 (NKE),  ts-29 (XOM)
#
# Segmen I: ts-1 (AXP), ts-5 (CVX), ts-21 (PG), ts-28 (WMT)
#
# Segmen J: ts-4 (CSCO), ts-7 (DOW), ts-11 (INTC), ts-14 (KO), ts-26 (VZ), ts-27 (WBA)
#
# Segmen K:  ts-3 (CAT), ts-6 (DIS), ts-10 (IBM), ts-12 (JNJ), ts-13 (JPM),  ts-18 (MSFT), ts-22 (TRV), ts-24 (UTX)

# %%
def adjusted_volatility(price_list):
  price_list_after=price_list.copy()
  price_list_after.pop(0) #remove first element 
  price_list.pop() #remove last element
  return (np.mean(np.abs(pd.Series(price_list_after)-pd.Series(price_list))))

# %%
#Segment A
print('Segment A Adjusted Volatility: {}'.format(adjusted_volatility(df_yfinance_AAPL['Open'].tolist())))

#Segment B
print('Segment B Adjusted Volatility: {}'.format(adjusted_volatility(df_yfinance_full_MMM['Open'].tolist())))

#Segment C
print('Segment C Adjusted Volatility: {}'.format(adjusted_volatility(df_yfinance_full_V['Open'].tolist())))

#Segment D
print('Segment D Adjusted Volatility: {}'.format(adjusted_volatility(df_yfinance_full_UNH['Open'].tolist())))

#Segment E
print('Segment E Adjusted Volatility: {}'.format(adjusted_volatility(df_yfinance_BA['Open'].tolist())))

#Segment F
print('Segment F Adjusted Volatility: {}'.format(adjusted_volatility(df_yfinance_full_PFE['Open'].tolist())))

#Segment G
print('Segment G Adjusted Volatility: {}'.format(np.mean([adjusted_volatility(df_yfinance_full_GS['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_HD['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_MCD['Open'].tolist())])))

#Segment H
print('Segment H Adjusted Volatility: {}'.format(np.mean([adjusted_volatility(df_yfinance_full_MRK['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_NKE['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_XOM['Open'].tolist())])))

#Segment I
print('Segment I Adjusted Volatility: {}'.format(np.mean([adjusted_volatility(df_yfinance_AXP['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_CVX['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_PG['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_WMT['Open'].tolist())])))

#Segment J
print('Segment J Adjusted Volatility: {}'.format(np.mean([adjusted_volatility(df_yfinance_full_CSCO['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_DOW['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_INTC['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_KO['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_VZ['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_WBA['Open'].tolist())])))

#Segment K
print('Segment K Adjusted Volatility: {}'.format(np.mean([adjusted_volatility(df_yfinance_full_CAT['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_DIS['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_IBM['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_JNJ['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_JPM['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_MSFT['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_TRV['Open'].tolist()),
                                                 adjusted_volatility(df_yfinance_full_UTX['Open'].tolist())])))
# Out:
# Segment A Adjusted Volatility: 0.754600834614757
# Segment B Adjusted Volatility: 0.628731031292435
# Segment C Adjusted Volatility: 0.5111782189571493
# Segment D Adjusted Volatility: 0.9791314903158955
# Segment E Adjusted Volatility: 1.5511152857436388
# Segment F Adjusted Volatility: 0.12446099027581167
# Segment G Adjusted Volatility: 0.6198146592240196
# Segment H Adjusted Volatility: 0.2502683072297472
# Segment I Adjusted Volatility: 0.3161233877487879
# Segment J Adjusted Volatility: 0.18789838506925802
# Segment K Adjusted Volatility: 0.4084203246619893

# %%
#Segment A
print('Segment A Volatility: {}'.format(np.std(df_yfinance_AAPL['Open'])))

#Segment B
print('Segment B Volatility: {}'.format(np.std(df_yfinance_full_MMM['Open'])))

#Segment C
print('Segment C Volatility: {}'.format(np.std(df_yfinance_full_V['Open'])))

#Segment D
print('Segment D Volatility: {}'.format(np.std(df_yfinance_full_UNH['Open'])))

#Segment E
print('Segment E Volatility: {}'.format(np.std(df_yfinance_BA['Open'])))

#Segment F
print('Segment F Volatility: {}'.format(np.std(df_yfinance_full_PFE['Open'])))

#Segment G
print('Segment G Volatility: {}'.format(np.mean([np.std(df_yfinance_full_GS['Open']),
                                                        np.std(df_yfinance_full_HD['Open']),
                                                        np.std(df_yfinance_full_MCD['Open'])])))

#Segment H
print('Segment H Volatility: {}'.format(np.mean([np.std(df_yfinance_full_MRK['Open']),
                                                        np.std(df_yfinance_full_NKE['Open']),
                                                        np.std(df_yfinance_full_XOM['Open'])])))

#Segment I
print('Segment I Volatility: {}'.format(np.mean([np.std(df_yfinance_AXP['Open']),
                                                        np.std(df_yfinance_full_CVX['Open']),
                                                        np.std(df_yfinance_full_PG['Open']),
                                                        np.std(df_yfinance_full_WMT['Open'])])))

#Segment J
print('Segment J Volatility: {}'.format(np.mean([np.std(df_yfinance_full_CSCO['Open']),
                                                        np.std(df_yfinance_full_DOW['Open']),
                                                        np.std(df_yfinance_full_INTC['Open']),
                                                        np.std(df_yfinance_full_KO['Open']),
                                                        np.std(df_yfinance_full_VZ['Open']),
                                                        np.std(df_yfinance_full_WBA['Open'])])))

#Segment K
print('Segment K Volatility: {}'.format(np.mean([np.std(df_yfinance_full_CAT['Open']),
                                                        np.std(df_yfinance_full_DIS['Open']),
                                                        np.std(df_yfinance_full_IBM['Open']),
                                                        np.std(df_yfinance_full_JNJ['Open']),
                                                        np.std(df_yfinance_full_JPM['Open']),
                                                        np.std(df_yfinance_full_MSFT['Open']),
                                                        np.std(df_yfinance_full_TRV['Open']),
                                                        np.std(df_yfinance_full_UTX['Open'])])))
# Out:
# Segment A Volatility: 33.98256379237507
# Segment B Volatility: 18.203062472070297
# Segment C Volatility: 15.227483062607067
# Segment D Volatility: 17.682514267393
# Segment E Volatility: 24.20508675934983
# Segment F Volatility: 2.834927998928856
# Segment G Volatility: 14.463081470336897
# Segment H Volatility: 4.678550698127503
# Segment I Volatility: 7.745748653403481
# Segment J Volatility: 4.155932839146484
# Segment K Volatility: 9.543067138775175

# %% [markdown]
# Segment E has the highest adjusted volatility and the second highest volatility. Then we will use Segment E (Boeing ) for further analysis.
